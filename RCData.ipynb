# %%
import pandas as pd
import matplotlib.pyplot as plt

#importing all csv files as objects
restaurantCred = pd.read_csv('Desktop/DataScience/RCDATA/chefmozaccepts.csv', sep= ",",header='infer')
restaurantCuisine = pd.read_csv('Desktop/DataScience/RCDATA/chefmozcuisine.csv', sep= ",",header='infer')
restaurantHours = pd.read_csv('Desktop/DataScience/RCDATA/chefmozhours4.csv', sep= ",",header='infer')
restaurantParking = pd.read_csv('Desktop/DataScience/RCDATA/chefmozparking.csv', sep= ",",header='infer')

#restaurantSummary = pd.read_csv('Desktop/DataScience/RCDATA/geoplaces2.csv', sep= ",",header='infer')
finalRating = pd.read_csv('Desktop/DataScience/RCDATA/rating_final.csv', sep= ",",header='infer')

userCuisine = pd.read_csv('Desktop/DataScience/RCDATA/usercuisine.csv', sep= ",",header='infer')
userPayment = pd.read_csv('Desktop/DataScience/RCDATA/userpayment.csv', sep= ",",header='infer')
userSummary = pd.read_csv('Desktop/DataScience/RCDATA/userprofile.csv', sep= ",",header='infer')

# %%
import matplotlib as mpl

userPayment.groupby(['Upayment']).count().plot(kind= 'bar')
plt.show()

# %%
cashCounter = 0
americanCounter = 0
bankCounter = 0
masterCounter = 0 
visaCounter = 0
for i in range(0, len(userPayment)):
    if userPayment.iloc[i]['Upayment'] == 'cash':
        cashCounter = cashCounter +1
        #print (userPayment.iloc[i]['userID'])
    elif userPayment.iloc[i]['Upayment'] == 'American_Express':
        americanCounter = americanCounter +1
        #print (userPayment.iloc[i]['userID'])
    elif userPayment.iloc[i]['Upayment'] == 'bank_debit_cards':
        bankCounter = bankCounter +1
        #print (userPayment.iloc[i]['userID'])
    elif userPayment.iloc[i]['Upayment'] == 'MasterCard-Eurocard':
        masterCounter = masterCounter +1
        #print (userPayment.iloc[i]['userID'])
    elif userPayment.iloc[i]['Upayment'] == 'VISA':
        visaCounter = visaCounter +1
        #print (userPayment.iloc[i]['userID'])

#print percentage of people who use cash
print(100*(cashCounter / len(userPayment)))
#print percentage of people who use American Express
print(100*(americanCounter / len(userPayment)) ) 
#print percentage of people who  bank or debit cards
print(100*(bankCounter / len(userPayment)) ) 
#print percentage of people who use master cards
print(100*(masterCounter / len(userPayment)) ) 
#print percentage of people who use visa cards
print(100*(visaCounter / len(userPayment)) )
# Out:
# 74.01129943502825
# 1.694915254237288
# 12.429378531073446
# 2.2598870056497176
# 9.6045197740113

# %%
from pylab import rcParams
userCuisine.groupby(['Rcuisine']).count().plot(kind= 'bar')
plt.figure(figsize=(10000,30))
#rcParams['font.size'] = 50
#a.tick_params(labelsize=20)
#rcParams['figure.figsize'] = 15, 5
plt.show()

# %%
maxCuisine = ''

counter = 0
maximumCount = 0

for i in range(0, len(userCuisine)):
    for y in range(0, len(userCuisine)):
        if userCuisine.iloc[i]['Rcuisine'] == userCuisine.iloc[y]['Rcuisine']:
            counter = counter + 1
    
    if counter > maximumCount:
        maxCuisine = userCuisine.iloc[i]['Rcuisine']
        maximumCount = counter
    counter = 0
        
        
print(maxCuisine + " with count: ")
maximumCount
# Out:
# Mexican with count:
# 97

# %%
userSummary.describe()
# Out:
#          latitude   longitude   birth_year      weight      height
# count  138.000000  138.000000   138.000000  138.000000  138.000000
# mean    21.810389 -100.291857  1984.702899   64.869565    1.667536
# std      1.552529    0.869916    14.655364   17.214332    0.130473
# min     18.813348 -101.054680  1930.000000   40.000000    1.200000
# 25%     22.126029 -100.983000  1987.000000   53.000000    1.600000
# 50%     22.150496 -100.937789  1989.000000   65.000000    1.690000
# 75%     22.186642  -99.183252  1991.000000   74.750000    1.750000
# max     23.771030  -99.067106  1994.000000  120.000000    2.000000

# %%
restaurantCuisine.groupby(['Rcuisine']).count().plot(kind= 'bar')
plt.figure(figsize=(10000,30))
plt.show()

# %%
mexicanCounter = 0
internationalCounter = 0
dutchbelgianCounter = 0
americanCounter = 0 
italianCounter = 0
for i in range(0, len(userCuisine)):
    if userCuisine.iloc[i]['Rcuisine'] == 'Mexican':
        mexicanCounter = mexicanCounter +1
        #print (userPayment.iloc[i]['userID'])
    elif userCuisine.iloc[i]['Rcuisine'] == 'International':
        internationalCounter = internationalCounter +1
        #print (userPayment.iloc[i]['userID'])
    elif userCuisine.iloc[i]['Rcuisine'] == 'Dutch-Belgian':
        dutchbelgianCounter = dutchbelgianCounter +1
        #print (userPayment.iloc[i]['userID'])
    elif userCuisine.iloc[i]['Rcuisine'] == 'American':
        americanCounter = americanCounter +1
        #print (userPayment.iloc[i]['userID'])
    elif userCuisine.iloc[i]['Rcuisine'] == 'Italian':
        italianCounter = italianCounter +1
        #print (userPayment.iloc[i]['userID'])

#print percentage of people who prefer mexican
print(100*(mexicanCounter / len(userCuisine)))
#print percentage of people who prefer international
print(100*(internationalCounter / len(userCuisine)) ) 
#print percentage of people who  prefer dutch
print(100*(dutchbelgianCounter / len(userCuisine)) ) 
#print percentage of people who prefer american
print(100*(americanCounter / len(userCuisine)) ) 
#print percentage of people who prefer italian
print(100*(italianCounter / len(userCuisine)) )
# Out:
# 29.393939393939394
# 0.30303030303030304
# 0.30303030303030304
# 3.3333333333333335
# 2.1212121212121215

# %%
userSummary.birth_year.plot(kind= 'box')
plt.show()

# %%
userSummary.groupby(['budget']).count().plot(kind= 'bar')
plt.figure(figsize=(10000,30))
plt.show()

# %%
mediumBudgetUsers = pd.DataFrame({'mediumBudgetUserID':[0]*91}) #declare list, will have 91 elements
y = 0
for i in range(0, len(userSummary)):
    if userSummary.iloc[i]['budget'] == 'medium':
        mediumBudgetUsers.iloc[y] = userSummary.iloc[i]['userID']
        y = y + 1

mediumBudgetUsers #all users with a medium budget
# Out:
#    mediumBudgetUserID
# 0               U1001
# 1               U1004
# 2               U1005
# 3               U1006
# 4               U1009
# 5               U1010
# 6               U1011
# 7               U1012
# 8               U1013
# 9               U1014
# 10              U1015
# 11              U1016
# 12              U1017
# 13              U1019
# 14              U1020
# 15              U1021
# 16              U1022
# 17              U1025
# 18              U1026
# 19              U1028
# 20              U1030
# 21              U1031
# 22              U1032
# 23              U1034
# 24              U1035
# 25              U1036
# 26              U1039
# 27              U1040
# 28              U1041
# 29              U1043
# ..                ...
# 61              U1088
# 62              U1090
# 63              U1092
# 64              U1093
# 65              U1094
# 66              U1095
# 67              U1096
# 68              U1097
# 69              U1098
# ...

# %%
#users with medium budgets, what cuisine do they enjoy
x = 0

mediumBudgetCuisines = pd.DataFrame({'mediumBudgetUserID':[0]*151, 'Rcuisine':[0]*151})  #cuisines enjoyed by middle budget consumers
for i in range(0, len(userCuisine)):
    for y in range(0, len(mediumBudgetUsers)):
        if userCuisine.iloc[i]['userID'] == mediumBudgetUsers.iloc[y]['mediumBudgetUserID']:
            mediumBudgetCuisines.iloc[x] = userCuisine.iloc[i]['Rcuisine']
            mediumBudgetCuisines.iloc[x]['mediumBudgetUserID'] = userCuisine.iloc[i]['userID']
            x = x + 1
            
mediumBudgetCuisines
# Out:
# C:\Users\kevin\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                  Rcuisine mediumBudgetUserID
# 0                American           American
# 1                  Bakery              U1004
# 2        Breakfast-Brunch              U1004
# 3                Japanese              U1004
# 4            Contemporary              U1004
# 5                 Mexican              U1004
# 6                  Bagels              U1004
# 7        Cafe-Coffee_Shop              U1004
# 8    Continental-European              U1004
# 9               Cafeteria              U1004
# 10               American              U1005
# 11                Mexican              U1006
# 12                  Diner              U1009
# 13              Fast_Food              U1009
# ...

# %%
mediumBudgetCuisines.groupby(['Rcuisine']).count().plot(kind= 'bar')
plt.figure(figsize=(10000,30))
plt.show()

# %%
highBudgetUsers = pd.DataFrame({'highBudgetUserID':[0]*5}) #declare list, will have 5 elements
y = 0
for i in range(0, len(userSummary)):
    if userSummary.iloc[i]['budget'] == 'high':
        highBudgetUsers.iloc[y] = userSummary.iloc[i]['userID']
        y = y + 1

highBudgetUsers #all users with a high budget
# Out:
#   highBudgetUserID
# 0            U1042
# 1            U1045
# 2            U1071
# 3            U1099
# 4            U1107

# %%
#users with high budgets, what cuisine do they enjoy
x = 0

highBudgetCuisines = pd.DataFrame({'highBudgetUserID':[0]*8, 'Rcuisine':[0]*8})  #cuisines enjoyed by middle budget consumers
for i in range(0, len(userCuisine)):
    for y in range(0, len(highBudgetUsers)):
        if userCuisine.iloc[i]['userID'] == highBudgetUsers.iloc[y]['highBudgetUserID']:
            highBudgetCuisines.iloc[x] = userCuisine.iloc[i]['Rcuisine']
            highBudgetCuisines.iloc[x]['highBudgetUserID'] = userCuisine.iloc[i]['userID']
            x = x + 1
            
highBudgetCuisines
# Out:
# C:\Users\kevin\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          Rcuisine highBudgetUserID
# 0         Mexican          Mexican
# 1  Middle_Eastern            U1045
# 2         Mexican            U1045
# 3       Mongolian            U1045
# 4        Moroccan            U1045
# 5         Mexican            U1071
# 6         Mexican            U1099
# 7         Mexican            U1107

# %%
highBudgetCuisines.groupby(['Rcuisine']).count().plot(kind= 'bar')
plt.figure(figsize=(10000,30))
plt.show()

# %%
lowBudgetUsers = pd.DataFrame({'lowBudgetUserID':[0]*35}) #declare list, will have 35 elements
y = 0
for i in range(0, len(userSummary)):
    if userSummary.iloc[i]['budget'] == 'low':
        lowBudgetUsers.iloc[y] = userSummary.iloc[i]['userID']
        y = y + 1

lowBudgetUsers #all users with a low budget
# Out:
#    lowBudgetUserID
# 0            U1002
# 1            U1003
# 2            U1007
# 3            U1008
# 4            U1018
# 5            U1023
# 6            U1027
# 7            U1029
# 8            U1033
# 9            U1037
# 10           U1038
# 11           U1052
# 12           U1053
# 13           U1058
# 14           U1066
# 15           U1068
# 16           U1070
# 17           U1080
# 18           U1081
# 19           U1089
# 20           U1091
# 21           U1101
# 22           U1102
# 23           U1109
# 24           U1115
# 25           U1120
# 26           U1124
# 27           U1125
# 28           U1126
# 29           U1127
# 30           U1128
# 31           U1129
# 32           U1135
# 33           U1136
# 34           U1137

# %%
#users with low budgets, what cuisine do they enjoy
x = 0

lowBudgetCuisines = pd.DataFrame({'lowBudgetUserID':[0]*164, 'Rcuisine':[0]*164})  #cuisines enjoyed by low budget consumers
for i in range(0, len(userCuisine)):
    for y in range(0, len(lowBudgetUsers)):
        if userCuisine.iloc[i]['userID'] == lowBudgetUsers.iloc[y]['lowBudgetUserID']:
            lowBudgetCuisines.iloc[x] = userCuisine.iloc[i]['Rcuisine']
            lowBudgetCuisines.iloc[x]['lowBudgetUserID'] = userCuisine.iloc[i]['userID']
            x = x + 1
            
lowBudgetCuisines
# Out:
# C:\Users\kevin\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#               Rcuisine lowBudgetUserID
# 0              Mexican         Mexican
# 1              Mexican           U1003
# 2               Family           U1007
# 3     Cafe-Coffee_Shop           U1008
# 4              Mexican           U1008
# 5                Juice           U1008
# 6             Hawaiian           U1008
# 7             Hot_Dogs           U1008
# 8       Latin_American           U1008
# 9               Korean           U1008
# 10            American           U1008
# 11           Cafeteria           U1008
# 12             Italian           U1008
# 13             Mexican           U1018
# 14             Mexican           U1023
# 15              Family           U1027
# ...

# %%
lowBudgetCuisines.groupby(['Rcuisine']).count().plot(kind= 'bar')
plt.figure(figsize=(10000,30))
plt.show()

# %%
#users with high budgets, what cuisine do they enjoy
x = 0

highBudgetPayment = pd.DataFrame({'highBudgetUserID':[0]*7, 'Upayment':[0]*7})  #payment enjoyed by high budget consumers
for i in range(0, len(userPayment)):
    for y in range(0, len(highBudgetUsers)):
        if userPayment.iloc[i]['userID'] == highBudgetUsers.iloc[y]['highBudgetUserID']:
            highBudgetPayment.iloc[x] = userPayment.iloc[i]['Upayment']
            highBudgetPayment.iloc[x]['highBudgetUserID'] = userPayment.iloc[i]['userID']
            x = x + 1
            
highBudgetPayment
# Out:
# C:\Users\kevin\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#            Upayment  highBudgetUserID
# 0  bank_debit_cards  bank_debit_cards
# 1              cash             U1045
# 2              cash             U1071
# 3              cash             U1099
# 4              VISA             U1099
# 5  bank_debit_cards             U1107
# 6              cash             U1107

# %%
finalRating.describe()
# Out:
#              placeID       rating  food_rating  service_rating
# count    1161.000000  1161.000000  1161.000000     1161.000000
# mean   134192.041344     1.199828     1.215332        1.090439
# std      1100.916275     0.773282     0.792294        0.790844
# min    132560.000000     0.000000     0.000000        0.000000
# 25%    132856.000000     1.000000     1.000000        0.000000
# 50%    135030.000000     1.000000     1.000000        1.000000
# 75%    135059.000000     2.000000     2.000000        2.000000
# max    135109.000000     2.000000     2.000000        2.000000

# %%
tempFinalRating.plot(kind= 'box')
plt.figure(figsize=(10000,30))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-41c5ffe302cb> in <module>()
# ----> 1 tempFinalRating.plot(kind= 'box')
#       2 plt.figure(figsize=(10000,30))
#       3 plt.show()
#
# NameError: name 'tempFinalRating' is not defined

# %%
americanCuisine = 0


for i in range(0, len(userCuisine)):
    if userCuisine.iloc[i]['Rcuisine'] == 'American':
        americanCuisine = americanCuisine + 1
        
    
        
        
print(americanCuisine)
# Out:
# 11

# %%
restaurantParking.groupby(['parking_lot']).count().plot(kind= 'bar')
plt.figure(figsize=(10000,30))
plt.show()

# %%
mydata = userSummary[["height", "birth_year"]]
# Now plot with matplotlib
vals = mydata.values
plt.scatter(vals[:, 0], vals[:, 1])
plt.show()

# %%
x = 0

highBudgetDressPreference = pd.DataFrame({'highBudgetUserID':[0]*5, 'dress_preference':[0]*5})  #dress preference for high budget consumers
for i in range(0, len(userSummary)):
    for y in range(0, len(highBudgetUsers)):
        if userSummary.iloc[i]['userID'] == highBudgetUsers.iloc[y]['highBudgetUserID']:
            highBudgetDressPreference.iloc[x] = userSummary.iloc[i]['dress_preference']
            highBudgetDressPreference.iloc[x]['highBudgetUserID'] = userSummary.iloc[i]['userID']
            x = x + 1
            
highBudgetDressPreference
# Out:
# C:\Users\kevin\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dress_preference highBudgetUserID
# 0    no preference    no preference
# 1          elegant            U1045
# 2           formal            U1071
# 3         informal            U1099
# 4    no preference            U1107

# %%
#users with low budgets, what cuisine do they enjoy
x = 0

lowBudgetDress = pd.DataFrame({'lowBudgetUserID':[0]*35, 'dress_preference':[0]*35})  
for i in range(0, len(userSummary)):
    for y in range(0, len(lowBudgetUsers)):
        if userSummary.iloc[i]['userID'] == lowBudgetUsers.iloc[y]['lowBudgetUserID']:
            lowBudgetDress.iloc[x] = userSummary.iloc[i]['dress_preference']
            lowBudgetDress.iloc[x]['lowBudgetUserID'] = userSummary.iloc[i]['userID']
            x = x + 1
            
lowBudgetDress
# Out:
# C:\Users\kevin\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    dress_preference lowBudgetUserID
# 0          informal        informal
# 1            formal           U1003
# 2          informal           U1007
# 3            formal           U1008
# 4            formal           U1018
# 5          informal           U1023
# 6     no preference           U1027
# 7            formal           U1029
# 8     no preference           U1033
# 9     no preference           U1037
# 10    no preference           U1038
# 11    no preference           U1052
# 12         informal           U1053
# 13           formal           U1058
# 14         informal           U1066
# 15         informal           U1068
# 16         informal           U1070
# ...

# %%
lowBudgetDress.groupby(['dress_preference']).count().plot(kind= 'bar')
plt.figure(figsize=(10000,30))
plt.show()

# %%
x = 0
lowBudgetRating = pd.DataFrame({'lowBudgetUserID':[0]*316, 'placeID':[0]*316, 'rating': [0] *316, 'food_rating': [0] *316, 'service_rating': [0] *316}) 
for i in range(0, len(finalRating)):
    for y in range(0, len(lowBudgetUsers)):
        if finalRating.iloc[i]['userID'] == lowBudgetUsers.iloc[y]['lowBudgetUserID']:
            lowBudgetRating.iloc[x]['lowBudgetUserID'] = finalRating.iloc[i]['userID']
            lowBudgetRating.iloc[x]['placeID'] = finalRating.iloc[i]['placeID']
            lowBudgetRating.iloc[x]['rating'] = finalRating.iloc[i]['rating']
            lowBudgetRating.iloc[x]['food_rating'] = finalRating.iloc[i]['food_rating']
            lowBudgetRating.iloc[x]['service_rating'] = finalRating.iloc[i]['service_rating']
            x = x + 1

 


lowBudgetRating
# Out:
#      food_rating  lowBudgetUserID  placeID  rating  service_rating
# 0              1                0   135104       1               2
# 1              0                0   132740       0               0
# 2              1                0   132663       1               1
# 3              0                0   132732       0               0
# 4              1                0   132630       1               1
# 5              2                0   132608       2               1
# 6              1                0   132609       1               1
# 7              1                0   132613       1               0
# 8              0                0   132715       0               0
# 9              0                0   132717       0               0
# 10             2                0   135011       1               2
# 11             1                0   134999       1               1
# 12             2                0   134975       2               2
# ...

# %%
x = 0
highBudgetRating = pd.DataFrame({'highBudgetUserID':[0]*42, 'placeID':[0]*42, 'rating': [0] *42, 'food_rating': [0] *42, 'service_rating': [0] *42}) 
for i in range(0, len(finalRating)):
    for y in range(0, len(highBudgetUsers)):
        if finalRating.iloc[i]['userID'] == highBudgetUsers.iloc[y]['highBudgetUserID']:
            highBudgetRating.iloc[x]['lowBudgetUserID'] = finalRating.iloc[i]['userID']
            highBudgetRating.iloc[x]['placeID'] = finalRating.iloc[i]['placeID']
            highBudgetRating.iloc[x]['rating'] = finalRating.iloc[i]['rating']
            highBudgetRating.iloc[x]['food_rating'] = finalRating.iloc[i]['food_rating']
            highBudgetRating.iloc[x]['service_rating'] = finalRating.iloc[i]['service_rating']
            x = x + 1

 


highBudgetRating
# Out:
#     food_rating  highBudgetUserID  placeID  rating  service_rating
# 0             2                 0   132660       2               1
# 1             2                 0   132584       2               2
# 2             2                 0   132733       2               2
# 3             2                 0   132862       2               2
# 4             1                 0   135063       2               2
# 5             2                 0   135052       2               2
# 6             2                 0   135060       1               2
# 7             2                 0   135042       2               2
# 8             2                 0   132825       2               2
# 9             2                 0   132856       2               2
# 10            2                 0   135032       2               2
# 11            1                 0   132834       1               1
# 12            2                 0   135039       2               2
# ...

# %%
x = 0
mediumBudgetRating = pd.DataFrame({'mediumBudgetUserID':[0]*734, 'placeID':[0]*734, 'rating': [0] *734, 'food_rating': [0] *734, 'service_rating': [0] *734}) 
for i in range(0, len(finalRating)):
    for y in range(0, len(mediumBudgetUsers)):
        if finalRating.iloc[i]['userID'] == mediumBudgetUsers.iloc[y]['mediumBudgetUserID']:
            mediumBudgetRating.iloc[x]['mediumBudgetUserID'] = finalRating.iloc[i]['userID']
            mediumBudgetRating.iloc[x]['placeID'] = finalRating.iloc[i]['placeID']
            mediumBudgetRating.iloc[x]['rating'] = finalRating.iloc[i]['rating']
            mediumBudgetRating.iloc[x]['food_rating'] = finalRating.iloc[i]['food_rating']
            mediumBudgetRating.iloc[x]['service_rating'] = finalRating.iloc[i]['service_rating']
            x = x + 1

 


mediumBudgetRating
# Out:
#      food_rating  mediumBudgetUserID  placeID  rating  service_rating
# 0              2                   0   135085       2               2
# 1              2                   0   135038       2               1
# 2              2                   0   132825       2               2
# 3              2                   0   135060       1               2
# 4              2                   0   132584       2               2
# 5              1                   0   132733       1               1
# 6              2                   0   132732       1               2
# 7              0                   0   132630       1               1
# 8              0                   0   135104       0               0
# 9              0                   0   132560       1               0
# 10             2                   0   132584       1               1
# 11             0                   0   132732       0               2
# ...

# %%
lowBudgetRating.describe()
# Out:
#        food_rating  lowBudgetUserID        placeID      rating  service_rating
# count   316.000000            316.0     316.000000  316.000000      316.000000
# mean      1.117089              0.0  134185.003165    1.136076        1.044304
# std       0.753126              0.0    1095.783560    0.741403        0.728947
# min       0.000000              0.0  132561.000000    0.000000        0.000000
# 25%       1.000000              0.0  132862.000000    1.000000        1.000000
# 50%       1.000000              0.0  135038.000000    1.000000        1.000000
# 75%       2.000000              0.0  135062.000000    2.000000        2.000000
# max       2.000000              0.0  135108.000000    2.000000        2.000000

# %%
mediumBudgetRating.describe()
# Out:
#        food_rating  mediumBudgetUserID        placeID      rating  \
# count   734.000000               734.0     734.000000  734.000000
# mean      1.237057                 0.0  134170.279292    1.208447
# std       0.806481                 0.0    1110.294699    0.786228
# min       0.000000                 0.0  132560.000000    0.000000
# 25%       1.000000                 0.0  132846.000000    1.000000
# 50%       1.000000                 0.0  135026.000000    1.000000
# 75%       2.000000                 0.0  135058.000000    2.000000
# max       2.000000                 0.0  135109.000000    2.000000
#
#        service_rating
# count      734.000000
# mean         1.091281
# std          0.808283
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          2.000000

# %%
highBudgetRating.describe()
# Out:
#        food_rating  highBudgetUserID        placeID     rating  service_rating
# count    42.000000              42.0      42.000000  42.000000       42.000000
# mean      1.595238               0.0  134242.976190   1.476190        1.452381
# std       0.627015               0.0    1085.652877   0.671296        0.739228
# min       0.000000               0.0  132584.000000   0.000000        0.000000
# 25%       1.000000               0.0  132856.000000   1.000000        1.000000
# 50%       2.000000               0.0  135029.000000   2.000000        2.000000
# 75%       2.000000               0.0  135049.500000   2.000000        2.000000
# max       2.000000               0.0  135085.000000   2.000000        2.000000

# %%
finalRating.describe()
# Out:
#              placeID       rating  food_rating  service_rating
# count    1161.000000  1161.000000  1161.000000     1161.000000
# mean   134192.041344     1.199828     1.215332        1.090439
# std      1100.916275     0.773282     0.792294        0.790844
# min    132560.000000     0.000000     0.000000        0.000000
# 25%    132856.000000     1.000000     1.000000        0.000000
# 50%    135030.000000     1.000000     1.000000        1.000000
# 75%    135059.000000     2.000000     2.000000        2.000000
# max    135109.000000     2.000000     2.000000        2.000000

# %%
restaurantSummary = pd.read_csv('Desktop/DataScience/RCDATA/editedRestaurants.csv', sep= ",",header='infer')

# %%
rating = 0
x = 0
food_rating = 0
service_rating = 0
times = 1
restaurantAverageRating = pd.DataFrame({'placeID':[0]*130, 'total_rating':[0]*130, 'total_food_rating': [0] *130, 'total_service_rating': [0] *130, 'number_of_ratings': [0] *130}) 

for i in range(0, len(restaurantSummary)):
    for y in range(0, len(finalRating)):
        if restaurantSummary.iloc[i]['placeID'] == finalRating.iloc[y]['placeID']:
            rating = rating + finalRating.iloc[y]['rating']
            food_rating = food_rating + finalRating.iloc[y]['food_rating']
            service_rating = service_rating + finalRating.iloc[y]['service_rating']
            times = times + 1  
    restaurantAverageRating.iloc[x]['placeID'] = restaurantSummary.iloc[x]['placeID']
    restaurantAverageRating.iloc[x]['total_rating'] = rating
    restaurantAverageRating.iloc[x]['total_food_rating'] = food_rating
    restaurantAverageRating.iloc[x]['total_service_rating'] = service_rating
    restaurantAverageRating.iloc[x]['number_of_ratings'] = times
    x = x + 1
    times = 1
    rating = 0
    food_rating = 0
    service_rating = 0
    
restaurantAverageRating
# Out:
#      number_of_ratings  placeID  total_food_rating  total_rating  \
# 0                    6   134999                  8             8
# 1                   33   132825                 43            41
# 2                   11   135106                 12            12
# 3                    5   132667                  8             5
# 4                    7   132613                  8             7
# 5                    5   135040                  1             1
# 6                    9   132732                  7             5
# 7                    9   132875                 10             9
# 8                    6   132609                  3             3
# 9                   10   135082                  7             7
# 10                   9   135070                  8             7
# 11                  13   135069                  6             6
# 12                  10   135065                 10            10
# ...

# %%
import pylab as plt
from mpldatacursor import datacursor

plt.bar(restaurantAverageRating['placeID'], restaurantAverageRating['average_rating']/restaurantAverageRating['number_of_ratings'], align='center')
datacursor(hover=True)
plt.show()

# %%
restaurantAverageRating['averageRating'] = restaurantAverageRating['total_rating']/restaurantAverageRating['number_of_ratings']
restaurantAverageRating['averageFoodRating'] = restaurantAverageRating['total_food_rating']/restaurantAverageRating['number_of_ratings']
restaurantAverageRating['averageServiceRating'] = restaurantAverageRating['total_service_rating']/restaurantAverageRating['number_of_ratings']

sortedRating = restaurantAverageRating.sort_values(by= 'averageRating')
sortedRating
# Out:
#      number_of_ratings  placeID  total_food_rating  total_rating  \
# 5                    5   135040                  1             1
# 103                  5   132654                  1             1
# 106                  5   132560                  4             2
# 122                  7   132663                  3             3
# 11                  13   135069                  6             6
# 114                  4   132766                  3             2
# 111                  6   132594                  6             3
# 85                   6   132885                  3             3
# 8                    6   132609                  3             3
# 15                   6   132870                  5             3
# 6                    9   132732                  7             5
# 20                   5   135033                  3             3
# 27                   5   132561                  4             3
# ...

# %%
x = 0
highPricedRestaurants = pd.DataFrame({'placeID':[0]*234, 'rating':[0] * 234, 'food_rating':[0] * 234, 'service_rating':[0] * 234}) 
for i in range(0, len(restaurantSummary)):
    for y in range(0, len(finalRating)):
        if restaurantSummary.iloc[i]['price'] == 'high':
            if finalRating.iloc[y]['placeID'] == restaurantSummary.iloc[i]['placeID']:
                highPricedRestaurants.iloc[x]['placeID'] = finalRating.iloc[y]['placeID']
                highPricedRestaurants.iloc[x]['rating'] = finalRating.iloc[y]['rating']
                highPricedRestaurants.iloc[x]['food_rating'] = finalRating.iloc[y]['food_rating']
                highPricedRestaurants.iloc[x]['service_rating'] = finalRating.iloc[y]['service_rating']
                x = x + 1

 


highPricedRestaurants
# Out:
#      food_rating  placeID  rating  service_rating
# 0              0   135040       0               0
# 1              0   135040       0               0
# 2              0   135040       0               0
# 3              1   135040       1               1
# 4              0   132875       0               0
# 5              2   132875       2               1
# 6              1   132875       1               1
# 7              2   132875       1               2
# 8              1   132875       1               1
# 9              0   132875       0               0
# 10             2   132875       2               2
# 11             2   132875       2               2
# 12             2   135065       2               2
# 13             0   135065       0               0
# 14             2   135065       2               0
# 15             2   135065       2               2
# 16             1   135065       1               1
# 17             0   135065       0               0
# ...

# %%
x = 0
mediumPricedRestaurants = pd.DataFrame({'placeID':[0]*577, 'rating':[0] * 577, 'food_rating':[0] * 577, 'service_rating':[0] * 577}) 
for i in range(0, len(restaurantSummary)):
    for y in range(0, len(finalRating)):
        if restaurantSummary.iloc[i]['price'] == 'medium':
            if finalRating.iloc[y]['placeID'] == restaurantSummary.iloc[i]['placeID']:
                mediumPricedRestaurants.iloc[x]['placeID'] = finalRating.iloc[y]['placeID']
                mediumPricedRestaurants.iloc[x]['rating'] = finalRating.iloc[y]['rating']
                mediumPricedRestaurants.iloc[x]['food_rating'] = finalRating.iloc[y]['food_rating']
                mediumPricedRestaurants.iloc[x]['service_rating'] = finalRating.iloc[y]['service_rating']
                x = x + 1

 


mediumPricedRestaurants
# Out:
#      food_rating  placeID  rating  service_rating
# 0              2   134999       2               2
# 1              1   134999       1               1
# 2              1   134999       1               1
# 3              2   134999       2               2
# 4              2   134999       2               2
# 5              2   135106       2               2
# 6              2   135106       2               2
# 7              1   135106       1               1
# 8              2   135106       2               2
# 9              0   135106       0               0
# 10             2   135106       2               2
# 11             0   135106       0               0
# 12             0   135106       0               0
# 13             2   135106       2               2
# 14             1   135106       1               1
# 15             2   132613       2               2
# 16             1   132613       1               0
# 17             0   132613       0               0
# ...

# %%
x = 0
lowPricedRestaurants = pd.DataFrame({'placeID':[0]*350, 'rating':[0] * 350, 'food_rating':[0] * 350, 'service_rating':[0] * 350}) 
for i in range(0, len(restaurantSummary)):
    for y in range(0, len(finalRating)):
        if restaurantSummary.iloc[i]['price'] == 'low':
            if finalRating.iloc[y]['placeID'] == restaurantSummary.iloc[i]['placeID']:
                lowPricedRestaurants.iloc[x]['placeID'] = finalRating.iloc[y]['placeID']
                lowPricedRestaurants.iloc[x]['rating'] = finalRating.iloc[y]['rating']
                lowPricedRestaurants.iloc[x]['food_rating'] = finalRating.iloc[y]['food_rating']
                lowPricedRestaurants.iloc[x]['service_rating'] = finalRating.iloc[y]['service_rating']
                x = x + 1

 


lowPricedRestaurants
# Out:
#      food_rating  placeID  rating  service_rating
# 0              2   132825       2               2
# 1              2   132825       2               2
# 2              2   132825       1               0
# 3              0   132825       1               1
# 4              2   132825       2               1
# 5              2   132825       2               2
# 6              2   132825       1               1
# 7              2   132825       2               2
# 8              1   132825       1               0
# 9              2   132825       2               2
# 10             2   132825       2               2
# 11             2   132825       2               2
# 12             0   132825       0               0
# 13             2   132825       1               1
# 14             1   132825       2               1
# 15             1   132825       1               0
# 16             0   132825       0               0
# 17             0   132825       0               0
# ...

# %%
lowPricedRestaurants.describe()
# Out:
#        food_rating        placeID      rating  service_rating
# count   350.000000     350.000000  350.000000      350.000000
# mean      1.134286  133287.077143    1.074286        0.920000
# std       0.809486     952.258448    0.760916        0.767835
# min       0.000000  132560.000000    0.000000        0.000000
# 25%       0.000000  132732.000000    0.000000        0.000000
# 50%       1.000000  132846.000000    1.000000        1.000000
# 75%       2.000000  132955.000000    2.000000        2.000000
# max       2.000000  135108.000000    2.000000        2.000000

# %%
mediumPricedRestaurants.describe()
# Out:
#        food_rating        placeID      rating  service_rating
# count   577.000000     577.000000  577.000000      577.000000
# mean      1.256499  134491.211438    1.253033        1.164645
# std       0.779554     978.935895    0.764963        0.776565
# min       0.000000  132584.000000    0.000000        0.000000
# 25%       1.000000  134987.000000    1.000000        1.000000
# 50%       1.000000  135038.000000    1.000000        1.000000
# 75%       2.000000  135062.000000    2.000000        2.000000
# max       2.000000  135109.000000    2.000000        2.000000

# %%
highPricedRestaurants.describe()
# Out:
#        food_rating        placeID      rating  service_rating
# count   234.000000     234.000000  234.000000      234.000000
# mean      1.235043  134807.923077    1.256410        1.162393
# std       0.791784     688.470229    0.793253        0.823030
# min       0.000000  132862.000000    0.000000        0.000000
# 25%       1.000000  135035.000000    1.000000        0.000000
# 50%       1.000000  135052.000000    1.000000        1.000000
# 75%       2.000000  135065.000000    2.000000        2.000000
# max       2.000000  135080.000000    2.000000        2.000000

# %%
finalRating.describe()
# Out:
#              placeID       rating  food_rating  service_rating
# count    1161.000000  1161.000000  1161.000000     1161.000000
# mean   134192.041344     1.199828     1.215332        1.090439
# std      1100.916275     0.773282     0.792294        0.790844
# min    132560.000000     0.000000     0.000000        0.000000
# 25%    132856.000000     1.000000     1.000000        0.000000
# 50%    135030.000000     1.000000     1.000000        1.000000
# 75%    135059.000000     2.000000     2.000000        2.000000
# max    135109.000000     2.000000     2.000000        2.000000

# %%
import matplotlib as mpl

userSummary.groupby(['religion']).count().plot(kind= 'bar')
plt.legend(loc=10,prop={'size':6})
plt.show()

# %%
import seaborn as sns
#seaborn factorplot to show edible/poisonous breakdown by different factors
df_forplot = userSummary.loc[:,('smoker','drink_level')]
g = sns.factorplot("smoker", col="drink_level", data=df_forplot,
                    kind="count", size=2.5, aspect=.8, col_wrap=6)

plt.show()

# %%
import matplotlib as mpl

userSummary.groupby(['activity']).count().plot(kind= 'bar')
plt.legend(loc=2,prop={'size':6})
plt.show()

# %%
x = 0
for i in range(0, len(userSummary)):
    if userSummary.iloc[i]['activity'] == 'student':
        x = x + 1
        
        

(x/len(userSummary))*100
# Out:
# 81.88405797101449

# %%
restaurantSummary['averageRating'] = restaurantSummary['totalRating']/restaurantSummary['numberOfRatings']
restaurantSummary['averageFoodRating'] = restaurantSummary['totalFoodRating']/restaurantSummary['numberOfRatings']
restaurantSummary['averageServiceRating'] = restaurantSummary['totalServiceRating']/restaurantSummary['numberOfRatings']

restaurantSummary
# Out:
#      placeID            alcohol   smoking_area dress_code     accessibility  \
# 0     134999  No_Alcohol_Served           none   informal  no_accessibility
# 1     132825  No_Alcohol_Served           none   informal        completely
# 2     135106          Wine-Beer    only at bar   informal         partially
# 3     132667  No_Alcohol_Served           none   informal        completely
# 4     132613  No_Alcohol_Served      permitted   informal        completely
# 5     135040          Wine-Beer           none   informal  no_accessibility
# 6     132732  No_Alcohol_Served           none     casual        completely
# 7     132875          Wine-Beer        section   informal  no_accessibility
# 8     132609  No_Alcohol_Served  not permitted   informal        completely
# 9     135082  No_Alcohol_Served           none   informal  no_accessibility
# 10    135070  No_Alcohol_Served           none   informal  no_accessibility
# ...

# %%
x = 0
restaurantSummary = pd.read_csv('Desktop/DataScience/RCDATA/editedRestaurants.csv', sep= ",",header='infer')
for i in range(0, len(restaurantSummary)):
    for y in range(0, len(sortedRating)):
        if restaurantSummary.iloc[i]['placeID'] == sortedRating.iloc[y]['placeID']:
            restaurantSummary.set_value(i, 'totalServiceRating', sortedRating.iloc[y]['total_service_rating'])
            restaurantSummary.set_value(i, 'totalFoodRating', sortedRating.iloc[y]['total_food_rating'])
            restaurantSummary.set_value(i, 'totalRating', sortedRating.iloc[y]['total_rating'])
            restaurantSummary.set_value(i, 'numberOfRatings', sortedRating.iloc[y]['number_of_ratings'])
            

 

restaurantSummary
# Out:
#      placeID            alcohol   smoking_area dress_code     accessibility  \
# 0     134999  No_Alcohol_Served           none   informal  no_accessibility
# 1     132825  No_Alcohol_Served           none   informal        completely
# 2     135106          Wine-Beer    only at bar   informal         partially
# 3     132667  No_Alcohol_Served           none   informal        completely
# 4     132613  No_Alcohol_Served      permitted   informal        completely
# 5     135040          Wine-Beer           none   informal  no_accessibility
# 6     132732  No_Alcohol_Served           none     casual        completely
# 7     132875          Wine-Beer        section   informal  no_accessibility
# 8     132609  No_Alcohol_Served  not permitted   informal        completely
# 9     135082  No_Alcohol_Served           none   informal  no_accessibility
# 10    135070  No_Alcohol_Served           none   informal  no_accessibility
# ...

# %%
sns.stripplot(x="averageFoodRating", y="alcohol", data=restaurantSummary, jitter=1);
plt.show()

# %%
sns.stripplot(x="averageRating", y="accessibility", data=restaurantSummary, jitter=1);
plt.show()

# %%
sns.stripplot(x="averageRating", y="price", data=restaurantSummary, jitter=1);
plt.show()

# %%
sns.stripplot(x="averageRating", y="Rambience", data=restaurantSummary, jitter=1);
plt.show()

# %%
sns.stripplot(x="averageRating", y="dress_code", data=restaurantSummary, jitter=1);
plt.show()

# %%
from sklearn import svm, datasets

# %%
#let us massage our data into shape
clusterRS = sortedRating.drop('placeID',1)

clusterRS.head(5)
clusterRS = clusterRS.as_matrix()
clusterRS
# Out:
# array([[  5.        ,   1.        ,   1.        ,   1.        ,
#           0.2       ,   0.2       ,   0.2       ],
#        [  5.        ,   1.        ,   1.        ,   1.        ,
#           0.2       ,   0.2       ,   0.2       ],
#        [  5.        ,   4.        ,   2.        ,   1.        ,
#           0.4       ,   0.8       ,   0.2       ],
#        [  7.        ,   3.        ,   3.        ,   4.        ,
#           0.42857143,   0.42857143,   0.57142857],
#        [ 13.        ,   6.        ,   6.        ,   9.        ,
#           0.46153846,   0.46153846,   0.69230769],
#        [  4.        ,   3.        ,   2.        ,   2.        ,
#           0.5       ,   0.75      ,   0.5       ],
#        [  6.        ,   6.        ,   3.        ,   3.        ,
#           0.5       ,   1.        ,   0.5       ],
#        [  6.        ,   3.        ,   3.        ,   2.        ,
#           0.5       ,   0.5       ,   0.33333333],
# ...

# %%
#all imports, library setups here
import pandas as pd
import numpy as np
import matplotlib

from scipy import stats, integrate

import matplotlib.pyplot as plt
# %matplotlib inline
import cufflinks as cf

import plotly
plotly.offline.init_notebook_mode()
import plotly.offline as py
import plotly.graph_objs as go
from plotly.graph_objs import *
print(pd.__version__)

import seaborn as sns
sns.set(color_codes=True)
#sns.set_context('poster')
plot_kwds = {'alpha' : 0.25, 's' : 80, 'linewidths':0}

import sklearn.cluster as cluster
import time
# Out:
# <script type='text/javascript'>if(!window.Plotly){define('plotly', function(require, exports, module) {/**
# * plotly.js v1.20.5
# * Copyright 2012-2016, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# ...

# %%
#write cluster plot function to help us
def plot_clusters(data, algorithm, args, kwds):
    start_time = time.time()
    labels = algorithm(*args, **kwds).fit_predict(data)
    end_time = time.time()
    palette = sns.color_palette('deep', np.unique(labels).max() + 1)
    colors = [palette[x] if x >= 0 else (0.0, 0.0, 0.0) for x in labels]
    plt.scatter(data.T[0], data.T[1], c=colors, **plot_kwds)
    frame = plt.gca()
    frame.axes.get_xaxis().set_visible(False)
    frame.axes.get_yaxis().set_visible(False)
    plt.title('Clusters found by {}'.format(str(algorithm.__name__)), fontsize=24)
    plt.text(-0.5, 0.7, 'Clustering took {:.2f} s'.format(end_time - start_time), fontsize=14)

# %%
import sklearn.cluster as cluster
plot_clusters(clusterRS, cluster.KMeans, (), {'n_clusters':4})

# %%
# kernel based 
#meanshift
# determine mean shift vector [with lots of similar points along this vector space]
# move ("shift") the mean towards higher density region
# dependence on kernel instead of distance metric [kernel = weighting function]
plot_clusters(clusterRS, cluster.MeanShift, (0.2,), {'cluster_all':False})

# %%
x = 0
for i in range(0, len(userSummary)):
    if userSummary.iloc[i]['religion'] == 'Catholic':
        x = x + 1
        
        

(x/len(userSummary))*100
# Out:
# 71.73913043478261

# %%
x = 0
for i in range(0, len(userSummary)):
    if userSummary.iloc[i]['smoker'] == 'false':
        x = x + 1
        
        

(x/len(userSummary))*100
# Out:
# 78.98550724637681

# %%
nus2 = userSummary.drop('drink_level',1)
nus3 = nus2.drop('transport',1)
nus4 = nus3.drop('marital_status',1)
nus5 = nus4.drop('hijos',1)
nus6 = nus5.drop('interest',1)
nus7 = nus6.drop('personality',1)
nus8 = nus7.drop('religion',1)
nus9 = nus8.drop('activity',1)
nus10 = nus9.drop('color',1)

nus10
# Out:
#     userID   latitude   longitude smoker dress_preference  ambience  \
# 0    U1001  22.139997 -100.978803  false         informal    family
# 1    U1002  22.150087 -100.983325  false         informal    family
# 2    U1003  22.119847 -100.946527  false           formal    family
# 3    U1004  18.867000  -99.183000  false         informal    family
# 4    U1005  22.183477 -100.959891  false    no preference    family
# 5    U1006  22.150000 -100.983000   true    no preference   friends
# 6    U1007  22.118464 -100.938256  false         informal  solitary
# 7    U1008  22.122989 -100.923811  false           formal  solitary
# 8    U1009  22.159427 -100.990448  false           formal    family
# 9    U1010  22.190889 -100.998669  false    no preference   friends
# 10   U1011  23.724972  -99.152856  false    no preference    family
# 11   U1012  18.813348  -99.243697  false           formal    family
# 12   U1013  22.174624 -100.993873  false    no preference   friends
# ...

# %%
nus11 = nus10.drop('ambience',1)
nus11
# Out:
#     userID   latitude   longitude smoker dress_preference  birth_year  weight  \
# 0    U1001  22.139997 -100.978803  false         informal        1989      69
# 1    U1002  22.150087 -100.983325  false         informal        1990      40
# 2    U1003  22.119847 -100.946527  false           formal        1989      60
# 3    U1004  18.867000  -99.183000  false         informal        1940      44
# 4    U1005  22.183477 -100.959891  false    no preference        1992      65
# 5    U1006  22.150000 -100.983000   true    no preference        1989      75
# 6    U1007  22.118464 -100.938256  false         informal        1989      60
# 7    U1008  22.122989 -100.923811  false           formal        1989      68
# 8    U1009  22.159427 -100.990448  false           formal        1991      75
# 9    U1010  22.190889 -100.998669  false    no preference        1987      40
# 10   U1011  23.724972  -99.152856  false    no preference        1989      68
# ...

# %%
for i in range(0, len(nus11)):
    if nus11.iloc[i]['smoker'] == 'true':
        nus11.set_value(i, 'smoker', 1)
    else:
        nus11.set_value(i, 'smoker', 0)
    if nus11.iloc[i]['budget'] == 'low':
        nus11.set_value(i, 'budget', 0)
    elif nus11.iloc[i]['budget'] == 'medium':
        nus11.set_value(i, 'budget', 1)
    elif nus11.iloc[i]['budget'] == 'high':
        nus11.set_value(i, 'budget', 2)
    if nus11.iloc[i]['dress_preference'] == 'informal':
        nus11.set_value(i, 'dress_preference', 0)
    elif nus11.iloc[i]['dress_preference'] == 'no preference':
        nus11.set_value(i, 'dress_preference', 1)
    elif nus11.iloc[i]['dress_preference'] == 'formal':
        nus11.set_value(i, 'dress_preference', 2)
    elif nus11.iloc[i]['dress_preference'] == 'elegant':
        nus11.set_value(i, 'dress_preference', 3)
        
         
        
nus11
# Out:
#     userID   latitude   longitude smoker dress_preference  birth_year  weight  \
# 0    U1001  22.139997 -100.978803      0                0        1989      69
# 1    U1002  22.150087 -100.983325      0                0        1990      40
# 2    U1003  22.119847 -100.946527      0                2        1989      60
# 3    U1004  18.867000  -99.183000      0                0        1940      44
# 4    U1005  22.183477 -100.959891      0                1        1992      65
# 5    U1006  22.150000 -100.983000      1                1        1989      75
# 6    U1007  22.118464 -100.938256      0                0        1989      60
# 7    U1008  22.122989 -100.923811      0                2        1989      68
# 8    U1009  22.159427 -100.990448      0                2        1991      75
# 9    U1010  22.190889 -100.998669      0                1        1987      40
# 10   U1011  23.724972  -99.152856      0                1        1989      68
# ...

# %%
smokerCount = 0
x = 0
budgetCount = 0 
y = 0
dressPrefCount = 0
z = 0
for i in range(0, len(nus11)):
    if nus11.iloc[i]['smoker'] != '?':
        smokerCount = smokerCount + nus11.iloc[i]['smoker']
        x = x + 1
    if nus11.iloc[i]['budget'] != '?':
        budgetCount = budgetCount + nus11.iloc[i]['budget']
        y = y +1
    if nus11.iloc[i]['dress_preference'] != '?':
        dressPrefCount = dressPrefCount + nus11.iloc[i]['dress_preference']
        z = z + 1
        
        
print((smokerCount/x))
print((budgetCount/y))
print((dressPrefCount/z))
# Out:
# 0.18840579710144928
# 0.7709923664122137
# 1.105263157894737

# %%
for i in range(0, len(nus11)):
    if nus11.iloc[i]['smoker'] == '?':
        nus11.set_value(i, 'smoker', smokerCount/x)
    if nus11.iloc[i]['budget'] == '?':
        nus11.set_value(i, 'budget', budgetCount/y)
    if nus11.iloc[i]['dress_preference'] == '?':
        nus11.set_value(i, 'dress_preference', dressPrefCount/z)
        
nus11
# Out:
#     userID   latitude   longitude smoker dress_preference  birth_year  weight  \
# 0    U1001  22.139997 -100.978803      0                0        1989      69
# 1    U1002  22.150087 -100.983325      0                0        1990      40
# 2    U1003  22.119847 -100.946527      0                2        1989      60
# 3    U1004  18.867000  -99.183000      0                0        1940      44
# 4    U1005  22.183477 -100.959891      0                1        1992      65
# 5    U1006  22.150000 -100.983000      1                1        1989      75
# 6    U1007  22.118464 -100.938256      0                0        1989      60
# 7    U1008  22.122989 -100.923811      0                2        1989      68
# 8    U1009  22.159427 -100.990448      0                2        1991      75
# 9    U1010  22.190889 -100.998669      0                1        1987      40
# 10   U1011  23.724972  -99.152856      0                1        1989      68
# ...

# %%
nus11 = nus11.drop('userID',1)
nus11 = nus11.as_matrix()
nus11
# Out:
# array([[22.139997, -100.978803, 0, ..., 69, 1, 1.77],
#        [22.150087, -100.983325, 0, ..., 40, 0, 1.87],
#        [22.119847, -100.946527, 0, ..., 60, 0, 1.69],
#        ...,
#        [22.149607, -100.997235, 1, ..., 50, 0, 1.6],
#        [22.144803, -100.94462299999999, 0, ..., 72, 0, 1.78],
#        [22.152884, -100.939663, 0, ..., 54, 1, 1.55]], dtype=object)

# %%
plot_clusters(nus11, cluster.KMeans, (), {'n_clusters':3})
plt.show()
